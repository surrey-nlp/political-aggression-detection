# %%
# !nvidia-smi
# Out:
# Sun Sep 11 18:39:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 1) Installing libraries

# %%
# !pip install transformers
# !pip install datasets
# !pip install wandb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datasets import load_dataset, Dataset

# %% [markdown]
# ## 2) Loading dataset (from HF)

# %%
# enter your personal read token

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
from datasets import load_dataset

aggression_dataset = load_dataset("IIIT-L/TRAC_plus_scrapped", use_auth_token=True)

print(aggression_dataset)
# Out:
# WARNING:datasets.builder:Using custom data configuration IIIT-L--TRAC_plus_scrapped-f6701c1f6fccd613
# Downloading and preparing dataset csv/IIIT-L--TRAC_plus_scrapped to /root/.cache/huggingface/datasets/IIIT-L___csv/IIIT-L--TRAC_plus_scrapped-f6701c1f6fccd613/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.45M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/188k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/186k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/IIIT-L___csv/IIIT-L--TRAC_plus_scrapped-f6701c1f6fccd613/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['Sentence', 'Label'],
#         num_rows: 11390
#     })
#     test: Dataset({
#         features: ['Sentence', 'Label'],
#         num_rows: 1424
#     })
#     validation: Dataset({
#         features: ['Sentence', 'Label'],
#         num_rows: 1424
#     })
# })

# %%
train_ds = aggression_dataset['train']
train_ds
# Out:
# Dataset({
#     features: ['Sentence', 'Label'],
#     num_rows: 11390
# })

# %% [markdown]
# ## 3) Converting to dataframe

# %%
aggression_dataset.set_format(type='pandas')
train_df = aggression_dataset['train'][:]
valid_df = aggression_dataset['validation'][:]

train_df.head()
# Out:
#                                             Sentence  Label
# 0                                  I am also lesbian      0
# 1  I think we should first gather the interested ...      0
# 2         It should be applicable to every relegion.      1
# 3  People in Tamilnadu have some sort of inferior...      1
# 4                                      where he gone      1

# %%
test_df = aggression_dataset['test'][:]

# %%
train_df['Label'].value_counts()
# Out:
# 0    5144
# 1    3685
# 2    2561
# Name: Label, dtype: int64

# %%
# 11390
# NAG-CAG-OAG (0-1-2) = 0.45-0.32-0.23

# %% [markdown]
# Seeing Distribution

# %%
disb_df = train_df.copy(deep=True)

# %%
disb_df['Words per sentence'] = disb_df['Sentence'].str.split().apply(len)
disb_df.boxplot('Words per sentence', by='Label', grid=False, showfliers=False, color='black')
plt.suptitle("")
plt.xlabel("")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ## 4) Tokenizing

# %%
from transformers import AutoTokenizer

# %%
model_ckpt = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/455k [00:00<?, ?B/s]

# %%
tokenizer.vocab_size
# Out:
# 30522

# %%
train_texts = list(train_df['Sentence'])
train_labels = list(train_df['Label'])

# %%
valid_texts = list(valid_df['Sentence'])
valid_labels = list(valid_df['Label'])

# %% [markdown]
# ## 5) Encoding train-valid

# %%
train_encodings = tokenizer(train_texts, truncation=True, padding=True)
valid_encodings = tokenizer(valid_texts, truncation=True, padding=True)

# %%
import torch

class AggressionDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_dataset = AggressionDataset(train_encodings, train_labels)
valid_dataset = AggressionDataset(valid_encodings, valid_labels)

# %% [markdown]
# ## 6) Setting classification model and evaluation metrics

# %%
import torch

# %%
# Use in case of CUDA memory error

# import gc

# gc.collect()
# torch.cuda.empty_cache()

# %%
from transformers import AutoModelForSequenceClassification

num_labels = 3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

def model_init():
    model = (AutoModelForSequenceClassification.from_pretrained(model_ckpt, num_labels=num_labels))
    return model
# Out:
# cuda

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, plot_confusion_matrix

def compute_metrics(pred):
  labels = pred.label_ids
  preds = pred.predictions.argmax(-1)

  f1 = f1_score(labels, preds, average='macro')
  precision = precision_score(labels, preds, average='macro')
  recall = recall_score(labels, preds, average='macro')
  acc = accuracy_score(labels, preds)
  return {'accuracy': acc, 'precision': precision, 'recall': recall, 'f1': f1}

# %% [markdown]
# ## 7) Fine-tuning, visualizing training, saving model to HF

# %%
import wandb

wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# %env WANDB_PROJECT = aggression_detection
# Out:
# env: WANDB_PROJECT=aggression_detection

# %%
from transformers import Trainer, TrainingArguments

# %%
# Defining hyperparameters
eval_batch_size = 16
logging_steps = len(train_texts) // eval_batch_size
model_name = f"{model_ckpt}-finetuned-combined-DS"
training_args = TrainingArguments(output_dir=model_name,
                                  num_train_epochs=4,
                                  learning_rate=4.932923543227153e-05,
                                  per_device_train_batch_size=8,
                                  per_device_eval_batch_size=16,
                                  weight_decay=0.17649239825343255,
                                  evaluation_strategy='steps',
                                  save_strategy='steps',
                                  max_steps=-1,
                                  warmup_ratio=0.0,
                                  seed=43,
                                  data_seed=4,
                                  metric_for_best_model="eval_f1",
                                  greater_is_better=True,
                                  load_best_model_at_end=True, 
                                  disable_tqdm=False,
                                  logging_steps=logging_steps,
                                  save_steps=logging_steps,
                                  log_level='info', 
                                  report_to="wandb", 
                                  run_name="bert-base-combined-DS",
                                  push_to_hub=True)

# %%
# import gc

# gc.collect()
# torch.cuda.empty_cache()

# %%
from torch import nn

class CustomTrainer(Trainer):
  def compute_loss(self, model, inputs, return_outputs=False):
    device = torch.device('cuda')
    inputs.to(device)
    labels = inputs.get("labels")
    # forward pass
    outputs = model(**inputs)
    logits = outputs.get("logits")
    # compute custom loss (suppose one has 3 labels with different weights)
    loss_fct = nn.CrossEntropyLoss(weight=torch.tensor([0.21, 0.33, 0.46]).to(device))
    loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
    return (loss, outputs) if return_outputs else loss

# %%
from transformers import EarlyStoppingCallback

# %%
# enter your personal write token here

from huggingface_hub import notebook_login
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
trainer = CustomTrainer(model_init=model_init,
                        args=training_args,
                        compute_metrics = compute_metrics,
                        train_dataset = train_dataset,
                        eval_dataset = valid_dataset,
                        tokenizer = tokenizer, 
                        callbacks = [EarlyStoppingCallback(early_stopping_patience = 2, early_stopping_threshold=0.0001)]
)

trainer.train()

# post-training analysis, testing, other logged code
wandb.finish()
# Out:
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.21.3",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpijaeuq9v
# Downloading pytorch_model.bin:   0%|          | 0.00/420M [00:00<?, ?B/s]
# storing https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# creating metadata file for /root/.cache/huggingface/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Cloning https://huggingface.co/SkyR/bert-base-uncased-finetuned-combined-DS into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/SkyR/bert-base-uncased-finetuned-combined-DS into local empty directory.
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.21.3",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 11390
#   Num Epochs = 4
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 5696
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: sky-s-the-limit. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>/content/wandb/run-20220911_184353-evh5wikv</code>
# Syncing run <strong><a href="https://wandb.ai/sky-s-the-limit/aggression_detection/runs/evh5wikv" target="_blank">bert-base-combined-DS</a></strong> to <a href="https://wandb.ai/sky-s-the-limit/aggression_detection" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#     <div>
#
#       <progress value='4266' max='5696' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4266/5696 58:49 < 19:43, 1.21 it/s, Epoch 2/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>711</td>
#       <td>0.900200</td>
#       <td>0.920090</td>
#       <td>0.612360</td>
#       <td>0.516208</td>
#       <td>0.536209</td>
#       <td>0.470588</td>
#     </tr>
#     <tr>
#       <td>1422</td>
#       <td>0.810900</td>
#       <td>0.988715</td>
#       <td>0.653792</td>
#       <td>0.650046</td>
#       <td>0.621718</td>
#       <td>0.623651</td>
#     </tr>
#     <tr>
#       <td>2133</td>
#       <td>0.608400</td>
#       <td>0.818709</td>
#       <td>0.676264</td>
#       <td>0.656491</td>
#       <td>0.657619</td>
#       <td>0.654461</td>
#     </tr>
#     <tr>
#       <td>2844</td>
#       <td>0.576600</td>
#       <td>0.903013</td>
#       <td>0.687500</td>
#       <td>0.667308</td>
#       <td>0.661287</td>
#       <td>0.660791</td>
#     </tr>
#     <tr>
#       <td>3555</td>
#       <td>0.335300</td>
#       <td>1.395081</td>
#       <td>0.665028</td>
#       <td>0.643532</td>
#       <td>0.638386</td>
#       <td>0.637861</td>
#     </tr>
#     <tr>
#       <td>4266</td>
#       <td>0.350300</td>
#       <td>1.484534</td>
#       <td>0.675562</td>
#       <td>0.652722</td>
#       <td>0.647193</td>
#       <td>0.647441</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1424
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-combined-DS/checkpoint-711
# Configuration saved in bert-base-uncased-finetuned-combined-DS/checkpoint-711/config.json
# Model weights saved in bert-base-uncased-finetuned-combined-DS/checkpoint-711/pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-711/tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-711/special_tokens_map.json
# tokenizer config file saved in bert-base-uncased-finetuned-combined-DS/tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-combined-DS/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1424
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-combined-DS/checkpoint-1422
# Configuration saved in bert-base-uncased-finetuned-combined-DS/checkpoint-1422/config.json
# Model weights saved in bert-base-uncased-finetuned-combined-DS/checkpoint-1422/pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-1422/tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-1422/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1424
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-combined-DS/checkpoint-2133
# Configuration saved in bert-base-uncased-finetuned-combined-DS/checkpoint-2133/config.json
# Model weights saved in bert-base-uncased-finetuned-combined-DS/checkpoint-2133/pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-2133/tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-2133/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1424
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-combined-DS/checkpoint-2844
# Configuration saved in bert-base-uncased-finetuned-combined-DS/checkpoint-2844/config.json
# Model weights saved in bert-base-uncased-finetuned-combined-DS/checkpoint-2844/pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-2844/tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-2844/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1424
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-combined-DS/checkpoint-3555
# Configuration saved in bert-base-uncased-finetuned-combined-DS/checkpoint-3555/config.json
# Model weights saved in bert-base-uncased-finetuned-combined-DS/checkpoint-3555/pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-3555/tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-3555/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1424
#   Batch size = 16
# Saving model checkpoint to bert-base-uncased-finetuned-combined-DS/checkpoint-4266
# Configuration saved in bert-base-uncased-finetuned-combined-DS/checkpoint-4266/config.json
# Model weights saved in bert-base-uncased-finetuned-combined-DS/checkpoint-4266/pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-4266/tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-combined-DS/checkpoint-4266/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from bert-base-uncased-finetuned-combined-DS/checkpoint-2844 (score: 0.6607907880287721).
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▅▇█▆▇</td></tr><tr><td>eval/f1</td><td>▁▇██▇█</td></tr><tr><td>eval/loss</td><td>▂▃▁▂▇█</td></tr><tr><td>eval/precision</td><td>▁▇▇█▇▇</td></tr><tr><td>eval/recall</td><td>▁▆██▇▇</td></tr><tr><td>eval/runtime</td><td>█▆▁▅█▆</td></tr><tr><td>eval/samples_per_second</td><td>▁▃█▄▁▃</td></tr><tr><td>eval/steps_per_second</td><td>▁▃█▃▁▃</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▄▄▅▅▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▄▄▅▅▇▇███</td></tr><tr><td>train/learning_rate</td><td>█▇▅▄▂▁</td></tr><tr><td>train/loss</td><td>█▇▄▄▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.67556</td></tr><tr><td>eval/f1</td><td>0.64744</td></tr><tr><td>eval/loss</td><td>1.48453</td></tr><tr><td>eval/precision</td><td>0.65272</td></tr><tr><td>eval/recall</td><td>0.64719</td></tr><tr><td>eval/runtime</td><td>48.8284</td></tr><tr><td>eval/samples_per_second</td><td>29.163</td></tr><tr><td>eval/steps_per_second</td><td>1.823</td></tr><tr><td>train/epoch</td><td>3.0</td></tr><tr><td>train/global_step</td><td>4266</td></tr><tr><td>train/learning_rate</td><td>1e-05</td></tr><tr><td>train/loss</td><td>0.3503</td></tr><tr><td>train/total_flos</td><td>8978482266550272.0</td></tr><tr><td>train/train_loss</td><td>0.59695</td></tr><tr><td>train/train_runtime</td><td>3535.5353</td></tr><tr><td>train/train_samples_per_second</td><td>12.886</td></tr><tr><td>train/train_steps_per_second</td><td>1.611</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">bert-base-combined-DS</strong>: <a href="https://wandb.ai/sky-s-the-limit/aggression_detection/runs/evh5wikv" target="_blank">https://wandb.ai/sky-s-the-limit/aggression_detection/runs/evh5wikv</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220911_184353-evh5wikv/logs</code>

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to bert-base-uncased-finetuned-combined-DS
# Configuration saved in bert-base-uncased-finetuned-combined-DS/config.json
# Model weights saved in bert-base-uncased-finetuned-combined-DS/pytorch_model.bin
# tokenizer config file saved in bert-base-uncased-finetuned-combined-DS/tokenizer_config.json
# Special tokens file saved in bert-base-uncased-finetuned-combined-DS/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# WARNING:huggingface_hub.repository:The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 3.34k/418M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/SkyR/bert-base-uncased-finetuned-combined-DS
#    182dd50..d64c6f6  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/SkyR/bert-base-uncased-finetuned-combined-DS
#    182dd50..d64c6f6  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Text Classification', 'type': 'text-classification'}, 'metrics': [{'name': 'Accuracy', 'type': 'accuracy', 'value': 0.675561797752809}, {'name': 'Precision', 'type': 'precision', 'value': 0.6527220061782412}, {'name': 'Recall', 'type': 'recall', 'value': 0.6471933898556552}, {'name': 'F1', 'type': 'f1', 'value': 0.6474413205200967}]}
# To https://huggingface.co/SkyR/bert-base-uncased-finetuned-combined-DS
#    d64c6f6..a049176  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/SkyR/bert-base-uncased-finetuned-combined-DS
#    d64c6f6..a049176  main -> main
# 'https://huggingface.co/SkyR/bert-base-uncased-finetuned-combined-DS/commit/d64c6f6bf9337ed2a2931b453cc0c73825fb3d01'

# %% [markdown]
# ## 8) Predictions and Results

# %%
test_texts = list(test_df['Sentence'])
test_labels = list(test_df['Label'])

# %%
test_encodings = tokenizer(test_texts, truncation=True, padding=True)

# %%
test_dataset = AggressionDataset(test_encodings, test_labels)

# %%
preds_output_test = trainer.predict(test_dataset)
# Out:
# ***** Running Prediction *****
#   Num examples = 1424
#   Batch size = 16

# %%
preds_output_test.metrics
# Out:
# {'test_loss': 0.8212020397186279,
#  'test_accuracy': 0.6973314606741573,
#  'test_precision': 0.6790147351377138,
#  'test_recall': 0.6806212462145874,
#  'test_f1': 0.6778372324921614,
#  'test_runtime': 45.2464,
#  'test_samples_per_second': 31.472,
#  'test_steps_per_second': 1.967}

# %%
y_preds_test = np.argmax(preds_output_test.predictions, axis=1)

# %%
y_valid_test = np.array(test_dataset.labels)

# %%
map_dt = {0:'NAG', 1:'CAG', 2:'OAG'}

# %%
print(classification_report(y_valid_test, y_preds_test, target_names=list(map_dt.values())))
# Out:
#               precision    recall  f1-score   support
#
#          NAG       0.87      0.77      0.82       643
#          CAG       0.58      0.65      0.61       461
#          OAG       0.58      0.62      0.60       320
#
#     accuracy                           0.70      1424
#    macro avg       0.68      0.68      0.68      1424
# weighted avg       0.71      0.70      0.70      1424

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_valid_trying = map(lambda x : map_dt[x], y_valid_test)
y_valid_trying = list(y_valid_trying)

y_preds_trying = map(lambda x : map_dt[x], y_preds_test)
y_preds_trying = list(y_preds_trying)

# %%
cm_labels = np.unique(y_valid_trying)
cm_array = confusion_matrix(y_valid_trying, y_preds_trying)
cm_array_df = pd.DataFrame(cm_array, index=cm_labels, columns=cm_labels)
sns.heatmap(cm_array_df, annot=True, annot_kws={"size": 12})
